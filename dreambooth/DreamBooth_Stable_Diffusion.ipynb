# %%
#@markdown Check type of GPU and VRAM available.
# !nvidia-smi --query-gpu=name,memory.total,memory.free --format=csv,noheader
# Out:
# Tesla T4, 15109 MiB, 15109 MiB

# %% [markdown]
# https://github.com/ShivamShrirao/diffusers/tree/main/examples/dreambooth

# %% [markdown]
# ## Install Requirements

# %%
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/examples/dreambooth/train_dreambooth.py
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/scripts/convert_diffusers_to_original_stable_diffusion.py
# %pip install -qq git+https://github.com/ShivamShrirao/diffusers
# %pip install -q -U --pre triton
# %pip install -q accelerate==0.12.0 transformers ftfy bitsandbytes gradio natsort
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done

# %%
#@title Login to HuggingFace 🤗

#@markdown You need to accept the model license before downloading or using the Stable Diffusion weights. Please, visit the [model card](https://huggingface.co/runwayml/stable-diffusion-v1-5), read the license and tick the checkbox if you agree. You have to be a registered user in 🤗 Hugging Face Hub, and you'll also need to use an access token for the code to work.
# https://huggingface.co/settings/tokens
# !mkdir -p ~/.huggingface
HUGGINGFACE_TOKEN = "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" #@param {type:"string"}
# !echo -n "{HUGGINGFACE_TOKEN}" > ~/.huggingface/token

# %% [markdown]
# ### Install xformers from precompiled wheel.

# %%
# %pip install -q https://github.com/metrolobo/xformers_wheels/releases/download/1d31a3ac_various_6/xformers-0.0.14.dev0-cp37-cp37m-linux_x86_64.whl
# These were compiled on Tesla T4, should also work on P100, thanks to https://github.com/metrolobo

# If precompiled wheels don't work, install it with the following command. It will take around 40 minutes to compile.
# %pip install git+https://github.com/facebookresearch/xformers@1d31a3a#egg=xformers
# Out:
#      |████████████████████████████████| 102.9 MB 101 kB/s

# %% [markdown]
# ## Settings and run

# %%
#@markdown If model weights should be saved directly in google drive (takes around 4-5 GB).
save_to_gdrive = True #@param {type:"boolean"}
if save_to_gdrive:
    from google.colab import drive
    drive.mount('/content/drive')

#@markdown Name/Path of the initial model.
MODEL_NAME = "runwayml/stable-diffusion-v1-5" #@param {type:"string"}

#@markdown Enter the directory name to save model at.

OUTPUT_DIR = "stable_diffusion_weights/dreambooth_aaron_hnatiw" #@param {type:"string"}
if save_to_gdrive:
    OUTPUT_DIR = "/content/drive/MyDrive/" + OUTPUT_DIR
else:
    OUTPUT_DIR = "/content/" + OUTPUT_DIR

print(f"[*] Weights will be saved at {OUTPUT_DIR}")

# !mkdir -p $OUTPUT_DIR
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [*] Weights will be saved at /content/drive/MyDrive/stable_diffusion_weights/dreambooth_aaron_hnatiw

# %% [markdown]
# # Start Training
#
# Use the table below to choose the best flags based on your memory and speed requirements. Tested on Tesla T4 GPU.
#
#
# | `fp16` | `train_batch_size` | `gradient_accumulation_steps` | `gradient_checkpointing` | `use_8bit_adam` | GB VRAM usage | Speed (it/s) |
# | ---- | ------------------ | ----------------------------- | ----------------------- | --------------- | ---------- | ------------ |
# | fp16 | 1                  | 1                             | TRUE                    | TRUE            | 9.92       | 0.93         |
# | no   | 1                  | 1                             | TRUE                    | TRUE            | 10.08      | 0.42         |
# | fp16 | 2                  | 1                             | TRUE                    | TRUE            | 10.4       | 0.66         |
# | fp16 | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 1.14         |
# | no   | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 0.49         |
# | fp16 | 1                  | 2                             | TRUE                    | TRUE            | 11.56      | 1            |
# | fp16 | 2                  | 1                             | FALSE                   | TRUE            | 13.67      | 0.82         |
# | fp16 | 1                  | 2                             | FALSE                   | TRUE            | 13.7       | 0.83          |
# | fp16 | 1                  | 1                             | TRUE                    | FALSE           | 15.79      | 0.77         |

# %% [markdown]
# Add `--gradient_checkpointing` flag for around 9.92 GB VRAM usage.
#
# remove `--use_8bit_adam` flag for full precision. Requires 15.79 GB with `--gradient_checkpointing` else 17.8 GB.
#
# remove `--train_text_encoder` flag to reduce memory usage further, degrades output quality.

# %%
# You can also add multiple concepts here. Try tweaking `--max_train_steps` accordingly.

concepts_list = [
    {
        "instance_prompt":      "photo of Aaron Hnatiw",
        "class_prompt":         "photo of a man",
        "instance_data_dir":    "/content/data/aaron_hnatiw",
        "class_data_dir":       "/content/data/man"
    },
#     {
#         "instance_prompt":      "photo of ukj person",
#         "class_prompt":         "photo of a person",
#         "instance_data_dir":    "/content/data/ukj",
#         "class_data_dir":       "/content/data/person"
#     }
]

# `class_data_dir` contains regularization images
import json
import os
for c in concepts_list:
    os.makedirs(c["instance_data_dir"], exist_ok=True)

with open("concepts_list.json", "w") as f:
    json.dump(concepts_list, f, indent=4)

# %%
#@markdown Upload your images by running this cell.

#@markdown OR

#@markdown You can use the file manager on the left panel to upload (drag and drop) to each `instance_data_dir` (it uploads faster)

import os
from google.colab import files
import shutil

for c in concepts_list:
    print(f"Uploading instance images for `{c['instance_prompt']}`")
    uploaded = files.upload()
    for filename in uploaded.keys():
        dst_path = os.path.join(c['instance_data_dir'], filename)
        shutil.move(filename, dst_path)

# %%
# !accelerate launch train_dreambooth.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --pretrained_vae_name_or_path="stabilityai/sd-vae-ft-mse" \
  --output_dir=$OUTPUT_DIR \
  --with_prior_preservation --prior_loss_weight=1.0 \
  --seed=1337 \
  --resolution=512 \
  --train_batch_size=1 \
  --train_text_encoder \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --gradient_accumulation_steps=1 \
  --learning_rate=1e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --num_class_images=50 \
  --sample_batch_size=4 \
  --max_train_steps=800 \
  --save_interval=10000 \
  --save_sample_prompt="photo of Aaron Hnatiw" \
  --concepts_list="concepts_list.json"

# Reduce the `--save_interval` to lower than `--max_train_steps` to save weights from intermediate steps.
# `--save_sample_prompt` can be same as `--instance_prompt` to generate intermediate samples (saved along with weights in samples directory).
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--num_cpu_threads_per_process` was set to `1` to improve out-of-box performance
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# Downloading: 100% 543/543 [00:00<00:00, 477kB/s]
# Fetching 15 files:   0% 0/15 [00:00<?, ?it/s]
# Downloading: 100% 342/342 [00:00<00:00, 295kB/s]
# Fetching 15 files:   7% 1/15 [00:02<00:35,  2.53s/it]
# Downloading: 100% 4.72k/4.72k [00:00<00:00, 2.84MB/s]
# Fetching 15 files:  20% 3/15 [00:05<00:19,  1.61s/it]
# Downloading:   0% 0.00/1.22G [00:00<?, ?B/s]
# Downloading:   0% 5.47M/1.22G [00:00<00:22, 54.7MB/s]
# Downloading:   1% 11.2M/1.22G [00:00<00:21, 56.0MB/s]
# Downloading:   2% 18.7M/1.22G [00:00<00:18, 64.9MB/s]
# Downloading:   2% 26.6M/1.22G [00:00<00:16, 70.6MB/s]
# Downloading:   3% 34.5M/1.22G [00:00<00:16, 73.5MB/s]
# Downloading:   3% 41.9M/1.22G [00:00<00:17, 67.2MB/s]
# Downloading:   4% 49.8M/1.22G [00:00<00:16, 70.9MB/s]
# Downloading:   5% 57.6M/1.22G [00:00<00:15, 73.2MB/s]
# Downloading:   5% 65.4M/1.22G [00:00<00:15, 74.4MB/s]
# Downloading:   6% 73.4M/1.22G [00:01<00:14, 76.2MB/s]
# Downloading:   7% 81.1M/1.22G [00:01<00:15, 73.6MB/s]
# Downloading:   7% 88.5M/1.22G [00:01<00:15, 73.3MB/s]
# Downloading:   8% 96.0M/1.22G [00:01<00:15, 73.7MB/s]
# Downloading:   8% 103M/1.22G [00:01<00:15, 73.3MB/s]
# Downloading:   9% 111M/1.22G [00:01<00:14, 75.2MB/s]
# Downloading:  10% 119M/1.22G [00:01<00:14, 75.7MB/s]
# Downloading:  10% 127M/1.22G [00:01<00:14, 75.2MB/s]
# Downloading:  11% 135M/1.22G [00:01<00:14, 76.5MB/s]
# Downloading:  12% 142M/1.22G [00:01<00:14, 76.6MB/s]
# Downloading:  12% 150M/1.22G [00:02<00:14, 72.6MB/s]
# Downloading:  13% 157M/1.22G [00:02<00:15, 67.8MB/s]
# Downloading:  14% 165M/1.22G [00:02<00:14, 71.3MB/s]
# Downloading:  14% 172M/1.22G [00:02<00:14, 71.6MB/s]
# Downloading:  15% 180M/1.22G [00:02<00:14, 73.5MB/s]
# Downloading:  15% 188M/1.22G [00:02<00:14, 70.0MB/s]
# Downloading:  16% 195M/1.22G [00:02<00:14, 71.6MB/s]
# Downloading:  17% 203M/1.22G [00:02<00:13, 73.7MB/s]
# Downloading:  17% 211M/1.22G [00:02<00:13, 74.7MB/s]
# Downloading:  18% 218M/1.22G [00:03<00:13, 72.6MB/s]
# Downloading:  19% 226M/1.22G [00:03<00:13, 73.3MB/s]
# Downloading:  19% 233M/1.22G [00:03<00:13, 72.7MB/s]
# Downloading:  20% 241M/1.22G [00:03<00:13, 73.9MB/s]
# Downloading:  20% 248M/1.22G [00:03<00:13, 74.1MB/s]
# Downloading:  98% 1.19G/1.22G [00:17<00:00, 60.5MB/s]
# Downloading:  98% 1.20G/1.22G [00:17<00:00, 55.8MB/s]
# Downloading:  99% 1.20G/1.22G [00:17<00:00, 60.9MB/s]
# Downloading: 100% 1.22G/1.22G [00:17<00:00, 68.9MB/s]
# Fetching 15 files:  27% 4/15 [00:24<01:23,  7.63s/it]
# Downloading: 100% 284/284 [00:00<00:00, 244kB/s]
# Fetching 15 files:  33% 5/15 [00:26<00:59,  5.96s/it]
# Downloading: 100% 617/617 [00:00<00:00, 531kB/s]
# Fetching 15 files:  40% 6/15 [00:29<00:43,  4.87s/it]
# Downloading:   0% 0.00/492M [00:00<?, ?B/s]
# Downloading:   2% 7.49M/492M [00:00<00:06, 74.9MB/s]
# Downloading:   3% 15.0M/492M [00:00<00:06, 75.2MB/s]
# Downloading:   5% 22.6M/492M [00:00<00:06, 74.2MB/s]
# Downloading:   6% 30.2M/492M [00:00<00:06, 75.2MB/s]
# Downloading:   8% 37.7M/492M [00:00<00:06, 72.9MB/s]
# Downloading:   9% 45.3M/492M [00:00<00:06, 73.8MB/s]
# Downloading:  11% 53.0M/492M [00:00<00:05, 74.8MB/s]
# Downloading:  12% 60.8M/492M [00:00<00:05, 75.7MB/s]
# Downloading:  14% 68.4M/492M [00:00<00:05, 75.5MB/s]
# Downloading:  15% 76.0M/492M [00:01<00:05, 75.9MB/s]
# Downloading:  17% 83.9M/492M [00:01<00:05, 76.8MB/s]
# Downloading:  19% 91.6M/492M [00:01<00:05, 73.2MB/s]
# Downloading:  20% 99.0M/492M [00:01<00:05, 71.0MB/s]
# Downloading:  22% 107M/492M [00:01<00:05, 73.0MB/s]
# Downloading:  23% 114M/492M [00:01<00:05, 71.7MB/s]
# Downloading:  25% 122M/492M [00:01<00:05, 72.9MB/s]
# Downloading:  26% 129M/492M [00:01<00:05, 70.2MB/s]
# Downloading:  28% 137M/492M [00:01<00:04, 71.9MB/s]
# Downloading:  29% 144M/492M [00:01<00:04, 73.3MB/s]
# Downloading:  31% 152M/492M [00:02<00:04, 75.0MB/s]
# Downloading:  32% 160M/492M [00:02<00:04, 71.2MB/s]
# Downloading:  34% 167M/492M [00:02<00:04, 72.2MB/s]
# Downloading:  35% 175M/492M [00:02<00:04, 72.9MB/s]
# Downloading:  37% 182M/492M [00:02<00:04, 72.3MB/s]
# Downloading:  38% 189M/492M [00:02<00:04, 72.2MB/s]
# Downloading:  40% 197M/492M [00:02<00:04, 73.3MB/s]
# Downloading:  42% 205M/492M [00:02<00:03, 74.5MB/s]
# Downloading:  43% 212M/492M [00:02<00:03, 75.7MB/s]
# Downloading:  45% 220M/492M [00:03<00:03, 68.6MB/s]
# Downloading:  46% 228M/492M [00:03<00:03, 70.6MB/s]
# Downloading:  48% 235M/492M [00:03<00:03, 72.8MB/s]
# Downloading:  49% 243M/492M [00:03<00:03, 69.9MB/s]
# Downloading:  51% 250M/492M [00:03<00:03, 71.5MB/s]
# Downloading:  52% 258M/492M [00:03<00:03, 71.5MB/s]
# Downloading:  54% 265M/492M [00:03<00:03, 72.3MB/s]
# Downloading:  55% 273M/492M [00:03<00:02, 74.6MB/s]
# Downloading:  57% 280M/492M [00:03<00:03, 66.4MB/s]
# Downloading:  58% 288M/492M [00:03<00:02, 68.7MB/s]
# Downloading:  60% 295M/492M [00:04<00:02, 70.8MB/s]
# Downloading:  62% 303M/492M [00:04<00:02, 71.3MB/s]
# Downloading:  63% 310M/492M [00:04<00:02, 71.6MB/s]
# Downloading:  65% 318M/492M [00:04<00:02, 73.6MB/s]
# Downloading:  66% 326M/492M [00:04<00:02, 74.8MB/s]
# Downloading:  68% 333M/492M [00:04<00:02, 73.1MB/s]
# Downloading:  69% 341M/492M [00:04<00:02, 74.8MB/s]
# Downloading:  71% 349M/492M [00:04<00:01, 75.9MB/s]
# Downloading:  72% 356M/492M [00:04<00:01, 75.4MB/s]
# Downloading:  74% 364M/492M [00:04<00:01, 75.7MB/s]
# Downloading:  76% 372M/492M [00:05<00:01, 75.5MB/s]
# Downloading:  77% 379M/492M [00:05<00:01, 74.4MB/s]
# Downloading:  79% 387M/492M [00:05<00:01, 74.8MB/s]
# Downloading:  80% 394M/492M [00:05<00:01, 68.5MB/s]
# Downloading:  82% 401M/492M [00:05<00:01, 68.6MB/s]
# Downloading:  83% 408M/492M [00:05<00:01, 68.7MB/s]
# Downloading:  84% 416M/492M [00:05<00:01, 70.8MB/s]
# Downloading:  86% 423M/492M [00:05<00:00, 71.4MB/s]
# Downloading:  87% 430M/492M [00:05<00:00, 68.6MB/s]
# Downloading:  89% 437M/492M [00:06<00:00, 69.5MB/s]
# Downloading:  90% 445M/492M [00:06<00:00, 70.4MB/s]
# Downloading:  92% 453M/492M [00:06<00:00, 73.1MB/s]
# Downloading:  93% 460M/492M [00:06<00:00, 71.6MB/s]
# Downloading:  95% 468M/492M [00:06<00:00, 73.3MB/s]
# Downloading:  97% 476M/492M [00:06<00:00, 74.7MB/s]
# Downloading:  98% 483M/492M [00:06<00:00, 72.3MB/s]
# Downloading: 100% 492M/492M [00:06<00:00, 72.6MB/s]
# Fetching 15 files:  47% 7/15 [00:37<00:46,  5.87s/it]
# Downloading:   0% 0.00/525k [00:00<?, ?B/s]
# Downloading:   8% 42.0k/525k [00:00<00:02, 179kB/s]
# Downloading:  16% 86.0k/525k [00:00<00:02, 183kB/s]
# Downloading:  37% 197k/525k [00:00<00:01, 314kB/s]
# Downloading: 100% 525k/525k [00:00<00:00, 554kB/s]
# Fetching 15 files:  53% 8/15 [00:41<00:36,  5.21s/it]
# Downloading: 100% 472/472 [00:00<00:00, 415kB/s]
# Fetching 15 files:  60% 9/15 [00:43<00:26,  4.40s/it]
# Downloading: 100% 806/806 [00:00<00:00, 533kB/s]
# Fetching 15 files:  67% 10/15 [00:46<00:19,  3.85s/it]
# Downloading:   0% 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   0% 4.10k/1.06M [00:00<00:59, 17.7kB/s]
# Downloading:   3% 32.8k/1.06M [00:00<00:12, 80.1kB/s]
# Downloading:   8% 86.0k/1.06M [00:00<00:06, 148kB/s]
# Downloading:  20% 209k/1.06M [00:00<00:02, 299kB/s]
# Downloading:  41% 438k/1.06M [00:01<00:01, 547kB/s]
# Downloading: 100% 1.06M/1.06M [00:01<00:00, 759kB/s]
# Fetching 15 files:  73% 11/15 [00:50<00:15,  3.90s/it]
# Downloading: 100% 743/743 [00:00<00:00, 629kB/s]
# Fetching 15 files:  80% 12/15 [00:52<00:10,  3.51s/it]
# Downloading:   0% 0.00/3.44G [00:00<?, ?B/s]
# Downloading:   0% 7.28M/3.44G [00:00<00:47, 72.8MB/s]
# Downloading:   0% 14.9M/3.44G [00:00<00:45, 74.8MB/s]
# Downloading:   1% 22.4M/3.44G [00:00<00:48, 71.0MB/s]
# Downloading:   1% 30.1M/3.44G [00:00<00:46, 73.4MB/s]
# Downloading:   1% 38.1M/3.44G [00:00<00:44, 75.6MB/s]
# Downloading:   1% 45.7M/3.44G [00:00<00:44, 75.7MB/s]
# Downloading:   2% 53.3M/3.44G [00:00<00:44, 75.6MB/s]
# Downloading:   2% 60.9M/3.44G [00:00<00:44, 75.7MB/s]
# Downloading:   2% 68.5M/3.44G [00:00<00:44, 75.6MB/s]
# Downloading:   2% 76.3M/3.44G [00:01<00:43, 76.5MB/s]
# Downloading:   2% 84.1M/3.44G [00:01<00:43, 77.0MB/s]
# Downloading:   3% 91.8M/3.44G [00:01<00:43, 76.7MB/s]
# Downloading:   3% 99.5M/3.44G [00:01<00:44, 75.0MB/s]
# Downloading:   3% 107M/3.44G [00:01<00:44, 75.6MB/s]
# Downloading:   3% 115M/3.44G [00:01<00:46, 71.5MB/s]
# Downloading:   4% 122M/3.44G [00:01<00:45, 72.5MB/s]
# Downloading:   4% 130M/3.44G [00:01<00:44, 73.6MB/s]
# Downloading:   4% 137M/3.44G [00:01<00:45, 73.0MB/s]
# Downloading:   4% 145M/3.44G [00:01<00:44, 73.2MB/s]
# Downloading:   4% 152M/3.44G [00:02<00:48, 67.6MB/s]
# Downloading:   5% 159M/3.44G [00:02<00:47, 69.2MB/s]
# Downloading:   5% 167M/3.44G [00:02<00:46, 70.1MB/s]
# Downloading:   5% 174M/3.44G [00:02<00:45, 71.2MB/s]
# Downloading:   5% 181M/3.44G [00:02<00:46, 70.0MB/s]
# Downloading:   5% 188M/3.44G [00:02<00:46, 69.7MB/s]
# Downloading:   6% 196M/3.44G [00:02<00:45, 71.6MB/s]
# Downloading:   6% 203M/3.44G [00:02<00:45, 71.6MB/s]
# Downloading:   6% 210M/3.44G [00:02<00:44, 71.9MB/s]
# Downloading:   6% 217M/3.44G [00:02<00:46, 68.8MB/s]
# Downloading:   7% 224M/3.44G [00:03<00:47, 67.3MB/s]
# Downloading:   7% 232M/3.44G [00:03<00:46, 69.0MB/s]
# Downloading:   7% 239M/3.44G [00:03<00:46, 69.4MB/s]
# Downloading:   7% 246M/3.44G [00:03<00:45, 70.0MB/s]
# Downloading:   7% 253M/3.44G [00:03<00:51, 62.3MB/s]
# Downloading:   8% 259M/3.44G [00:03<00:50, 62.4MB/s]
# Downloading:   8% 266M/3.44G [00:03<00:49, 63.5MB/s]
# Downloading:   8% 272M/3.44G [00:03<00:49, 64.0MB/s]
# Downloading:   8% 279M/3.44G [00:03<00:48, 65.3MB/s]
# Downloading:   8% 287M/3.44G [00:04<00:46, 67.8MB/s]
# Downloading:   9% 294M/3.44G [00:04<00:45, 69.2MB/s]
# Downloading:   9% 301M/3.44G [00:04<00:44, 70.6MB/s]
# Downloading:   9% 308M/3.44G [00:04<00:44, 70.2MB/s]
# Downloading:   9% 316M/3.44G [00:04<00:44, 70.8MB/s]
# Downloading:   9% 323M/3.44G [00:04<00:43, 71.6MB/s]
# Downloading:  10% 331M/3.44G [00:04<00:42, 73.0MB/s]
# Downloading:  10% 338M/3.44G [00:04<00:42, 73.2MB/s]
# Downloading:  10% 345M/3.44G [00:04<00:41, 73.7MB/s]
# Downloading:  10% 353M/3.44G [00:04<00:41, 73.5MB/s]
# Downloading:  10% 360M/3.44G [00:05<00:42, 73.0MB/s]
# Downloading:  11% 367M/3.44G [00:05<00:44, 69.0MB/s]
# Downloading:  11% 374M/3.44G [00:05<00:44, 69.2MB/s]
# Downloading:  11% 381M/3.44G [00:05<00:44, 68.7MB/s]
# Downloading:  11% 388M/3.44G [00:05<00:45, 67.3MB/s]
# Downloading:  12% 396M/3.44G [00:05<00:43, 70.3MB/s]
# Downloading:  12% 404M/3.44G [00:05<00:41, 72.3MB/s]
# Downloading:  12% 411M/3.44G [00:05<00:41, 73.4MB/s]
# Downloading:  12% 419M/3.44G [00:05<00:43, 70.1MB/s]
# Downloading:  12% 426M/3.44G [00:06<00:42, 71.0MB/s]
# Downloading:  13% 434M/3.44G [00:06<00:41, 73.2MB/s]
# Downloading:  13% 442M/3.44G [00:06<00:40, 74.6MB/s]
# Downloading:  13% 449M/3.44G [00:06<00:39, 75.1MB/s]
# Downloading:  13% 457M/3.44G [00:06<00:42, 69.7MB/s]
# Downloading:  14% 464M/3.44G [00:06<00:41, 71.3MB/s]
# Downloading:  14% 472M/3.44G [00:06<00:40, 73.9MB/s]
# Downloading:  14% 480M/3.44G [00:06<00:39, 75.7MB/s]
# Downloading:  14% 488M/3.44G [00:06<00:41, 71.0MB/s]
# Downloading:  14% 496M/3.44G [00:06<00:40, 73.1MB/s]
# Downloading:  15% 503M/3.44G [00:07<00:39, 73.7MB/s]
# Downloading:  15% 511M/3.44G [00:07<00:39, 73.4MB/s]
# Downloading:  15% 518M/3.44G [00:07<00:40, 71.4MB/s]
# Downloading:  15% 526M/3.44G [00:07<00:40, 72.0MB/s]
# Downloading:  15% 533M/3.44G [00:07<00:40, 71.7MB/s]
# Downloading:  16% 540M/3.44G [00:07<00:39, 73.4MB/s]
# Downloading:  16% 548M/3.44G [00:07<00:39, 73.6MB/s]
# Downloading:  16% 555M/3.44G [00:07<00:41, 69.8MB/s]
# Downloading:  16% 563M/3.44G [00:07<00:39, 72.7MB/s]
# Downloading:  35% 1.20G/3.44G [00:16<00:31, 71.0MB/s]
# Downloading:  35% 1.21G/3.44G [00:17<00:30, 72.2MB/s]
# Downloading:  35% 1.22G/3.44G [00:17<00:29, 74.2MB/s]
# Downloading:  36% 1.22G/3.44G [00:17<00:32, 67.2MB/s]
# Downloading:  36% 1.23G/3.44G [00:17<00:32, 68.6MB/s]
# Downloading:  36% 1.24G/3.44G [00:17<00:31, 70.4MB/s]
# Downloading:  36% 1.25G/3.44G [00:17<00:29, 73.2MB/s]
# Downloading:  36% 1.25G/3.44G [00:17<00:29, 74.2MB/s]
# Downloading:  37% 1.26G/3.44G [00:17<00:29, 73.8MB/s]
# Downloading:  37% 1.27G/3.44G [00:17<00:29, 73.8MB/s]
# Downloading:  37% 1.28G/3.44G [00:17<00:29, 73.8MB/s]
# Downloading:  37% 1.28G/3.44G [00:18<00:28, 75.2MB/s]
# Downloading:  38% 1.29G/3.44G [00:18<00:33, 64.8MB/s]
# Downloading:  38% 1.30G/3.44G [00:18<00:31, 67.0MB/s]
# Downloading:  38% 1.31G/3.44G [00:18<00:31, 68.3MB/s]
# Downloading:  38% 1.31G/3.44G [00:18<00:30, 69.5MB/s]
# Downloading:  38% 1.32G/3.44G [00:18<00:29, 72.4MB/s]
# Downloading:  39% 1.33G/3.44G [00:18<00:28, 74.0MB/s]
# Downloading:  39% 1.34G/3.44G [00:18<00:29, 71.9MB/s]
# Downloading:  39% 1.34G/3.44G [00:18<00:29, 70.4MB/s]
# Downloading:  39% 1.35G/3.44G [00:19<00:29, 71.5MB/s]
# Downloading:  40% 1.36G/3.44G [00:19<00:28, 72.3MB/s]
# Downloading:  40% 1.37G/3.44G [00:19<00:28, 73.9MB/s]
# Downloading:  40% 1.37G/3.44G [00:19<00:27, 74.3MB/s]
# Downloading:  40% 1.38G/3.44G [00:19<00:30, 66.5MB/s]
# Downloading:  40% 1.39G/3.44G [00:19<00:30, 68.3MB/s]
# Downloading:  41% 1.40G/3.44G [00:19<00:28, 71.2MB/s]
# Downloading:  41% 1.40G/3.44G [00:19<00:28, 70.8MB/s]
# Downloading:  41% 1.41G/3.44G [00:19<00:28, 71.4MB/s]
# Downloading:  41% 1.42G/3.44G [00:20<00:33, 59.9MB/s]
# Downloading:  41% 1.43G/3.44G [00:20<00:32, 62.7MB/s]
# Downloading:  42% 1.43G/3.44G [00:20<00:30, 64.9MB/s]
# Downloading:  42% 1.44G/3.44G [00:20<00:43, 45.9MB/s]
# Downloading:  42% 1.45G/3.44G [00:20<00:38, 52.2MB/s]
# Downloading:  42% 1.45G/3.44G [00:20<00:34, 57.8MB/s]
# Downloading:  43% 1.46G/3.44G [00:20<00:32, 61.0MB/s]
# Downloading:  43% 1.47G/3.44G [00:20<00:31, 63.4MB/s]
# Downloading:  43% 1.48G/3.44G [00:21<00:29, 66.1MB/s]
# Downloading:  43% 1.48G/3.44G [00:21<00:29, 66.6MB/s]
# Downloading:  43% 1.49G/3.44G [00:21<00:28, 68.9MB/s]
# Downloading:  52% 1.79G/3.44G [00:25<00:23, 69.4MB/s]
# Downloading:  52% 1.80G/3.44G [00:25<00:26, 63.0MB/s]
# Downloading:  53% 1.81G/3.44G [00:25<00:25, 64.8MB/s]
# Downloading:  53% 1.81G/3.44G [00:25<00:24, 67.6MB/s]
# Downloading:  53% 1.82G/3.44G [00:25<00:24, 66.9MB/s]
# Downloading:  53% 1.83G/3.44G [00:26<00:23, 69.5MB/s]
# Downloading:  53% 1.84G/3.44G [00:26<00:22, 71.1MB/s]
# Downloading:  54% 1.84G/3.44G [00:26<00:22, 72.4MB/s]
# Downloading:  54% 1.85G/3.44G [00:26<00:21, 74.1MB/s]
# Downloading:  54% 1.86G/3.44G [00:26<00:21, 74.8MB/s]
# Downloading:  54% 1.87G/3.44G [00:26<00:20, 75.2MB/s]
# Downloading:  55% 1.88G/3.44G [00:26<00:20, 76.1MB/s]
# Downloading:  55% 1.88G/3.44G [00:26<00:20, 77.1MB/s]
# Downloading:  55% 1.89G/3.44G [00:26<00:20, 77.2MB/s]
# Downloading:  55% 1.90G/3.44G [00:27<00:20, 74.5MB/s]
# Downloading:  55% 1.91G/3.44G [00:27<00:20, 75.6MB/s]
# Downloading:  56% 1.91G/3.44G [00:27<00:20, 75.4MB/s]
# Downloading:  56% 1.92G/3.44G [00:27<00:22, 67.5MB/s]
# Downloading:  56% 1.93G/3.44G [00:27<00:21, 70.8MB/s]
# Downloading:  56% 1.94G/3.44G [00:27<00:20, 72.2MB/s]
# Downloading:  57% 1.95G/3.44G [00:27<00:20, 74.4MB/s]
# Downloading:  57% 1.95G/3.44G [00:27<00:21, 70.6MB/s]
# Downloading:  57% 1.96G/3.44G [00:27<00:20, 71.6MB/s]
# Downloading:  57% 1.97G/3.44G [00:27<00:19, 73.7MB/s]
# Downloading:  57% 1.98G/3.44G [00:28<00:20, 72.7MB/s]
# Downloading:  58% 1.98G/3.44G [00:28<00:21, 68.5MB/s]
# Downloading:  58% 1.99G/3.44G [00:28<00:21, 66.8MB/s]
# Downloading:  58% 2.00G/3.44G [00:28<00:21, 68.6MB/s]
# Downloading:  58% 2.00G/3.44G [00:28<00:20, 71.4MB/s]
# Downloading:  59% 2.01G/3.44G [00:28<00:19, 74.0MB/s]
# Downloading:  59% 2.02G/3.44G [00:28<00:20, 68.8MB/s]
# Downloading:  59% 2.03G/3.44G [00:28<00:19, 71.4MB/s]
# Downloading:  59% 2.04G/3.44G [00:28<00:19, 73.6MB/s]
# Downloading:  59% 2.04G/3.44G [00:29<00:19, 71.8MB/s]
# Downloading:  60% 2.05G/3.44G [00:29<00:20, 68.5MB/s]
# Downloading:  60% 2.06G/3.44G [00:29<00:19, 70.8MB/s]
# Downloading:  60% 2.07G/3.44G [00:29<00:19, 72.0MB/s]
# Downloading:  60% 2.07G/3.44G [00:29<00:18, 74.3MB/s]
# Downloading:  61% 2.08G/3.44G [00:29<00:17, 75.9MB/s]
# Downloading:  61% 2.09G/3.44G [00:29<00:19, 70.1MB/s]
# Downloading:  69% 2.38G/3.44G [00:38<00:15, 66.9MB/s]
# Downloading:  69% 2.38G/3.44G [00:38<00:15, 69.2MB/s]
# Downloading:  70% 2.39G/3.44G [00:38<00:14, 70.4MB/s]
# Downloading:  70% 2.40G/3.44G [00:39<00:14, 70.7MB/s]
# Downloading:  70% 2.41G/3.44G [00:39<00:14, 71.9MB/s]
# Downloading:  70% 2.41G/3.44G [00:39<00:15, 66.0MB/s]
# Downloading:  70% 2.42G/3.44G [00:39<00:15, 67.1MB/s]
# Downloading:  71% 2.43G/3.44G [00:39<00:14, 69.7MB/s]
# Downloading:  71% 2.44G/3.44G [00:39<00:14, 70.5MB/s]
# Downloading:  71% 2.44G/3.44G [00:39<00:13, 71.7MB/s]
# Downloading:  71% 2.45G/3.44G [00:39<00:14, 68.2MB/s]
# Downloading:  71% 2.46G/3.44G [00:39<00:14, 68.5MB/s]
# Downloading:  72% 2.46G/3.44G [00:39<00:13, 70.3MB/s]
# Downloading:  72% 2.47G/3.44G [00:40<00:14, 68.9MB/s]
# Downloading:  72% 2.48G/3.44G [00:40<00:13, 70.6MB/s]
# Downloading:  72% 2.49G/3.44G [00:40<00:13, 69.6MB/s]
# Downloading:  73% 2.49G/3.44G [00:40<00:13, 70.5MB/s]
# Downloading:  73% 2.50G/3.44G [00:40<00:12, 72.1MB/s]
# Downloading:  73% 2.51G/3.44G [00:40<00:12, 73.4MB/s]
# Downloading:  73% 2.52G/3.44G [00:40<00:14, 64.1MB/s]
# Downloading:  73% 2.52G/3.44G [00:40<00:13, 67.2MB/s]
# Downloading:  74% 2.53G/3.44G [00:40<00:12, 70.1MB/s]
# Downloading:  74% 2.54G/3.44G [00:41<00:12, 72.0MB/s]
# Downloading:  74% 2.55G/3.44G [00:41<00:13, 68.0MB/s]
# Downloading:  74% 2.55G/3.44G [00:41<00:12, 69.4MB/s]
# Downloading:  74% 2.56G/3.44G [00:41<00:12, 69.1MB/s]
# Downloading:  75% 2.57G/3.44G [00:41<00:12, 71.9MB/s]
# Downloading:  75% 2.58G/3.44G [00:41<00:11, 72.9MB/s]
# Downloading:  75% 2.58G/3.44G [00:41<00:11, 72.3MB/s]
# Downloading:  75% 2.59G/3.44G [00:41<00:11, 73.9MB/s]
# Downloading:  76% 2.60G/3.44G [00:41<00:11, 74.4MB/s]
# Downloading:  76% 2.61G/3.44G [00:41<00:10, 75.6MB/s]
# Downloading:  76% 2.61G/3.44G [00:42<00:11, 68.8MB/s]
# Downloading:  76% 2.62G/3.44G [00:42<00:12, 67.5MB/s]
# Downloading:  76% 2.63G/3.44G [00:42<00:11, 69.0MB/s]
# Downloading:  77% 2.64G/3.44G [00:42<00:12, 65.8MB/s]
# Downloading:  77% 2.64G/3.44G [00:42<00:11, 67.4MB/s]
# Downloading:  77% 2.65G/3.44G [00:42<00:11, 69.9MB/s]
# Downloading:  77% 2.66G/3.44G [00:42<00:10, 71.2MB/s]
# Downloading:  77% 2.66G/3.44G [00:42<00:10, 71.5MB/s]
# Downloading:  78% 2.67G/3.44G [00:42<00:10, 72.1MB/s]
# Downloading:  78% 2.68G/3.44G [00:43<00:10, 73.1MB/s]
# Downloading:  78% 2.69G/3.44G [00:43<00:10, 72.3MB/s]
# Downloading:  78% 2.69G/3.44G [00:43<00:10, 73.8MB/s]
# Downloading:  79% 2.70G/3.44G [00:43<00:10, 72.5MB/s]
# Downloading:  79% 2.71G/3.44G [00:43<00:10, 72.6MB/s]
# Downloading:  79% 2.72G/3.44G [00:43<00:12, 59.4MB/s]
# Downloading:  79% 2.72G/3.44G [00:43<00:11, 62.5MB/s]
# Downloading:  79% 2.73G/3.44G [00:43<00:10, 64.8MB/s]
# Downloading:  80% 2.74G/3.44G [00:43<00:10, 65.5MB/s]
# Downloading:  80% 2.74G/3.44G [00:44<00:10, 67.4MB/s]
# Downloading:  80% 2.75G/3.44G [00:44<00:09, 69.0MB/s]
# Downloading:  80% 2.76G/3.44G [00:44<00:09, 69.3MB/s]
# Downloading:  80% 2.77G/3.44G [00:44<00:09, 71.2MB/s]
# Downloading:  81% 2.77G/3.44G [00:44<00:09, 70.8MB/s]
# Downloading:  81% 2.78G/3.44G [00:44<00:09, 71.5MB/s]
# Downloading:  81% 2.79G/3.44G [00:44<00:13, 48.4MB/s]
# Downloading:  81% 2.80G/3.44G [00:44<00:11, 53.7MB/s]
# Downloading:  82% 2.80G/3.44G [00:44<00:10, 58.9MB/s]
# Downloading:  82% 2.81G/3.44G [00:45<00:09, 62.8MB/s]
# Downloading:  82% 2.82G/3.44G [00:45<00:09, 64.7MB/s]
# Downloading:  82% 2.83G/3.44G [00:45<00:09, 67.7MB/s]
# Downloading:  82% 2.83G/3.44G [00:45<00:10, 58.9MB/s]
# Downloading:  83% 2.84G/3.44G [00:45<00:09, 62.0MB/s]
# Downloading:  83% 2.85G/3.44G [00:45<00:09, 64.9MB/s]
# Downloading:  83% 2.85G/3.44G [00:45<00:09, 62.1MB/s]
# Downloading:  83% 2.86G/3.44G [00:45<00:08, 66.1MB/s]
# Downloading:  83% 2.87G/3.44G [00:45<00:08, 69.0MB/s]
# Downloading:  84% 2.88G/3.44G [00:46<00:08, 69.8MB/s]
# Downloading:  84% 2.88G/3.44G [00:46<00:08, 69.2MB/s]
# Downloading:  84% 2.89G/3.44G [00:46<00:07, 70.0MB/s]
# Downloading:  84% 2.90G/3.44G [00:46<00:07, 71.8MB/s]
# Downloading:  84% 2.91G/3.44G [00:46<00:07, 71.9MB/s]
# Downloading:  85% 2.91G/3.44G [00:46<00:07, 74.3MB/s]
# Downloading:  85% 2.92G/3.44G [00:46<00:07, 69.1MB/s]
# Downloading:  85% 2.93G/3.44G [00:46<00:07, 68.9MB/s]
# Downloading:  85% 2.94G/3.44G [00:46<00:07, 71.0MB/s]
# Downloading:  86% 2.94G/3.44G [00:46<00:06, 71.7MB/s]
# Downloading:  86% 2.95G/3.44G [00:47<00:06, 69.9MB/s]
# Downloading:  86% 2.96G/3.44G [00:47<00:07, 67.8MB/s]
# Downloading:  86% 2.96G/3.44G [00:47<00:06, 69.4MB/s]
# Downloading:  86% 2.97G/3.44G [00:47<00:06, 69.3MB/s]
# Downloading:  87% 2.98G/3.44G [00:47<00:06, 67.3MB/s]
# Downloading:  87% 2.98G/3.44G [00:47<00:06, 65.4MB/s]
# Downloading:  87% 2.99G/3.44G [00:47<00:06, 67.0MB/s]
# Downloading:  87% 3.00G/3.44G [00:47<00:06, 69.7MB/s]
# Downloading:  87% 3.01G/3.44G [00:47<00:05, 72.2MB/s]
# Downloading:  88% 3.01G/3.44G [00:48<00:05, 72.4MB/s]
# Downloading:  88% 3.02G/3.44G [00:48<00:06, 68.4MB/s]
# Downloading:  88% 3.03G/3.44G [00:48<00:05, 69.5MB/s]
# Downloading:  88% 3.04G/3.44G [00:48<00:05, 71.6MB/s]
# Downloading:  89% 3.04G/3.44G [00:48<00:05, 70.2MB/s]
# Downloading:  89% 3.05G/3.44G [00:48<00:05, 69.6MB/s]
# Downloading:  89% 3.06G/3.44G [00:48<00:05, 72.2MB/s]
# Downloading:  89% 3.07G/3.44G [00:48<00:05, 74.0MB/s]
# Downloading:  89% 3.07G/3.44G [00:48<00:04, 73.9MB/s]
# Downloading:  90% 3.08G/3.44G [00:48<00:04, 73.7MB/s]
# Downloading:  90% 3.09G/3.44G [00:49<00:04, 73.8MB/s]
# Downloading:  90% 3.10G/3.44G [00:49<00:04, 72.4MB/s]
# Downloading:  90% 3.10G/3.44G [00:49<00:05, 61.5MB/s]
# Downloading:  90% 3.11G/3.44G [00:49<00:04, 66.0MB/s]
# Downloading:  91% 3.12G/3.44G [00:49<00:04, 64.2MB/s]
# Downloading:  91% 3.13G/3.44G [00:49<00:04, 67.4MB/s]
# Downloading:  91% 3.13G/3.44G [00:49<00:04, 68.4MB/s]
# Downloading:  91% 3.14G/3.44G [00:49<00:04, 70.3MB/s]
# Downloading:  92% 3.15G/3.44G [00:49<00:04, 71.5MB/s]
# Downloading:  92% 3.16G/3.44G [00:50<00:04, 69.5MB/s]
# Downloading:  92% 3.16G/3.44G [00:50<00:03, 70.8MB/s]
# Downloading:  92% 3.17G/3.44G [00:50<00:03, 72.2MB/s]
# Downloading:  92% 3.18G/3.44G [00:50<00:03, 72.1MB/s]
# Downloading:  93% 3.19G/3.44G [00:50<00:03, 73.4MB/s]
# Downloading:  93% 3.19G/3.44G [00:50<00:03, 71.6MB/s]
# Downloading:  93% 3.20G/3.44G [00:50<00:03, 73.1MB/s]
# Downloading:  93% 3.21G/3.44G [00:50<00:03, 73.8MB/s]
# Downloading:  94% 3.22G/3.44G [00:50<00:03, 73.7MB/s]
# Downloading:  94% 3.22G/3.44G [00:50<00:02, 75.0MB/s]
# Downloading:  94% 3.23G/3.44G [00:51<00:02, 74.9MB/s]
# Downloading:  94% 3.24G/3.44G [00:51<00:03, 65.2MB/s]
# Downloading:  94% 3.25G/3.44G [00:51<00:02, 69.0MB/s]
# Downloading:  95% 3.25G/3.44G [00:51<00:02, 72.3MB/s]
# Downloading:  95% 3.26G/3.44G [00:51<00:02, 72.7MB/s]
# Downloading:  95% 3.27G/3.44G [00:51<00:02, 67.1MB/s]
# Downloading:  95% 3.28G/3.44G [00:51<00:02, 70.0MB/s]
# Downloading:  96% 3.28G/3.44G [00:51<00:02, 70.9MB/s]
# Downloading:  96% 3.29G/3.44G [00:51<00:01, 73.4MB/s]
# Downloading:  96% 3.30G/3.44G [00:52<00:02, 67.6MB/s]
# Downloading:  96% 3.31G/3.44G [00:52<00:01, 70.6MB/s]
# Downloading:  96% 3.32G/3.44G [00:52<00:01, 73.5MB/s]
# Downloading:  97% 3.32G/3.44G [00:52<00:01, 73.8MB/s]
# Downloading:  97% 3.33G/3.44G [00:52<00:01, 75.4MB/s]
# Downloading:  97% 3.34G/3.44G [00:52<00:01, 69.3MB/s]
# Downloading:  97% 3.35G/3.44G [00:52<00:01, 71.2MB/s]
# Downloading:  98% 3.35G/3.44G [00:52<00:01, 73.3MB/s]
# Downloading:  98% 3.36G/3.44G [00:52<00:01, 75.1MB/s]
# Downloading:  98% 3.37G/3.44G [00:53<00:00, 69.3MB/s]
# Downloading:  98% 3.38G/3.44G [00:53<00:00, 72.0MB/s]
# Downloading:  98% 3.38G/3.44G [00:53<00:00, 73.5MB/s]
# Downloading:  99% 3.39G/3.44G [00:53<00:00, 73.8MB/s]
# Downloading:  99% 3.40G/3.44G [00:53<00:00, 70.6MB/s]
# Downloading:  99% 3.41G/3.44G [00:53<00:00, 72.4MB/s]
# Downloading:  99% 3.41G/3.44G [00:53<00:00, 71.3MB/s]
# Downloading: 100% 3.42G/3.44G [00:53<00:00, 73.9MB/s]
# Downloading: 100% 3.43G/3.44G [00:53<00:00, 74.7MB/s]
# Downloading: 100% 3.44G/3.44G [00:53<00:00, 63.7MB/s]
# Fetching 15 files:  87% 13/15 [01:48<00:38, 19.12s/it]
# Downloading: 100% 547/547 [00:00<00:00, 478kB/s]
# Fetching 15 files:  93% 14/15 [01:50<00:14, 14.13s/it]
# Downloading:   0% 0.00/335M [00:00<?, ?B/s]
# Downloading:   2% 7.56M/335M [00:00<00:04, 75.6MB/s]
# Downloading:   5% 15.1M/335M [00:00<00:04, 74.3MB/s]
# Downloading:   7% 22.5M/335M [00:00<00:04, 72.6MB/s]
# Downloading:   9% 30.1M/335M [00:00<00:04, 73.7MB/s]
# Downloading:  11% 37.8M/335M [00:00<00:03, 74.8MB/s]
# Downloading:  14% 45.3M/335M [00:00<00:03, 73.6MB/s]
# Downloading:  16% 52.6M/335M [00:00<00:03, 73.5MB/s]
# Downloading:  18% 60.0M/335M [00:00<00:03, 72.0MB/s]
# Downloading:  20% 67.2M/335M [00:00<00:04, 60.8MB/s]
# Downloading:  22% 74.4M/335M [00:01<00:04, 63.7MB/s]
# Downloading:  24% 81.5M/335M [00:01<00:03, 65.8MB/s]
# Downloading:  27% 88.8M/335M [00:01<00:03, 67.9MB/s]
# Downloading:  29% 96.0M/335M [00:01<00:03, 69.1MB/s]
# Downloading:  31% 104M/335M [00:01<00:03, 71.3MB/s]
# Downloading:  33% 111M/335M [00:01<00:03, 72.3MB/s]
# Downloading:  35% 118M/335M [00:01<00:02, 72.3MB/s]
# Downloading:  38% 126M/335M [00:01<00:02, 71.6MB/s]
# Downloading:  40% 133M/335M [00:01<00:02, 72.2MB/s]
# Downloading:  42% 140M/335M [00:01<00:02, 71.9MB/s]
# Downloading:  44% 148M/335M [00:02<00:02, 72.3MB/s]
# Downloading:  46% 155M/335M [00:02<00:02, 64.4MB/s]
# Downloading:  49% 162M/335M [00:02<00:02, 67.1MB/s]
# Downloading:  51% 169M/335M [00:02<00:02, 67.2MB/s]
# Downloading:  53% 176M/335M [00:02<00:02, 68.8MB/s]
# Downloading:  55% 184M/335M [00:02<00:02, 71.1MB/s]
# Downloading:  57% 192M/335M [00:02<00:01, 72.8MB/s]
# Downloading:  60% 199M/335M [00:02<00:01, 70.2MB/s]
# Downloading:  62% 206M/335M [00:02<00:01, 70.5MB/s]
# Downloading:  64% 214M/335M [00:03<00:01, 71.6MB/s]
# Downloading:  66% 221M/335M [00:03<00:01, 63.9MB/s]
# Downloading:  68% 229M/335M [00:03<00:01, 67.6MB/s]
# Downloading:  71% 236M/335M [00:03<00:01, 70.1MB/s]
# Downloading:  73% 244M/335M [00:03<00:01, 71.2MB/s]
# Downloading:  75% 251M/335M [00:03<00:01, 67.7MB/s]
# Downloading:  77% 258M/335M [00:03<00:01, 69.9MB/s]
# Downloading:  79% 266M/335M [00:03<00:00, 71.5MB/s]
# Downloading:  82% 273M/335M [00:03<00:00, 72.2MB/s]
# Downloading:  84% 281M/335M [00:04<00:00, 73.6MB/s]
# Downloading:  86% 288M/335M [00:04<00:00, 67.9MB/s]
# Downloading:  89% 296M/335M [00:04<00:00, 71.0MB/s]
# Downloading:  91% 304M/335M [00:04<00:00, 71.3MB/s]
# Downloading:  93% 312M/335M [00:04<00:00, 73.7MB/s]
# Downloading:  95% 319M/335M [00:04<00:00, 69.7MB/s]
# Downloading:  97% 326M/335M [00:04<00:00, 70.6MB/s]
# Downloading: 100% 335M/335M [00:04<00:00, 70.3MB/s]
# Fetching 15 files: 100% 15/15 [01:56<00:00,  7.78s/it]
# You have passed `None` for safety_checker to disable its functionality in <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'>. Note that this might lead to problems when using <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> and is not recommended.
# Generating class images: 100% 13/13 [07:14<00:00, 33.43s/it]
# Downloading: 100% 1.06M/1.06M [00:01<00:00, 741kB/s]
# Downloading: 100% 525k/525k [00:01<00:00, 451kB/s]
# Downloading: 100% 472/472 [00:00<00:00, 403kB/s]
# Downloading: 100% 806/806 [00:00<00:00, 681kB/s]
# Downloading: 100% 617/617 [00:00<00:00, 502kB/s]
# Downloading: 100% 492M/492M [00:12<00:00, 38.0MB/s]
# Caching latents: 100% 50/50 [00:10<00:00,  4.60it/s]
# Steps: 100% 800/800 [13:01<00:00,  1.05it/s, loss=0.266, lr=1e-6]
# Fetching 15 files: 100% 15/15 [00:00<00:00, 3833.22it/s]
# You have passed `None` for safety_checker to disable its functionality in <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'>. Note that this might lead to problems when using <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> and is not recommended.
#
# Generating samples:   0% 0/4 [00:00<?, ?it/s]
# Generating samples:  25% 1/4 [00:12<00:38, 12.73s/it]
# Generating samples:  50% 2/4 [00:21<00:21, 10.64s/it]
# Generating samples:  75% 3/4 [00:31<00:10, 10.01s/it]
# Generating samples: 100% 4/4 [00:40<00:00, 10.10s/it]
# [*] Weights saved at /content/drive/MyDrive/stable_diffusion_weights/dreambooth_aaron_hnatiw/800
# Steps: 100% 800/800 [14:06<00:00,  1.06s/it, loss=0.266, lr=1e-6]

# %%
#@markdown Specify the weights directory to use (leave blank for latest)
WEIGHTS_DIR = "" #@param {type:"string"}
if WEIGHTS_DIR == "":
    from natsort import natsorted
    from glob import glob
    import os
    WEIGHTS_DIR = natsorted(glob(OUTPUT_DIR + os.sep + "*"))[-1]
print(f"[*] WEIGHTS_DIR={WEIGHTS_DIR}")
# Out:
# [*] WEIGHTS_DIR=/content/drive/MyDrive/stable_diffusion_weights/dreambooth_aaron_hnatiw/800

# %% [markdown]
# ## Convert weights to ckpt to use in web UIs like AUTOMATIC1111.

# %%
#@markdown Run conversion.
ckpt_path = WEIGHTS_DIR + "/model.ckpt"

half_arg = ""
#@markdown  Whether to convert to fp16, takes half the space (2GB).
fp16 = True #@param {type: "boolean"}
if fp16:
    half_arg = "--half"
# !python convert_diffusers_to_original_stable_diffusion.py --model_path $WEIGHTS_DIR  --checkpoint_path $ckpt_path $half_arg
print(f"[*] Converted ckpt saved at {ckpt_path}")
# Out:
# Reshaping encoder.mid.attn_1.q.weight for SD format
# Reshaping encoder.mid.attn_1.k.weight for SD format
# Reshaping encoder.mid.attn_1.v.weight for SD format
# Reshaping encoder.mid.attn_1.proj_out.weight for SD format
# Reshaping decoder.mid.attn_1.q.weight for SD format
# Reshaping decoder.mid.attn_1.k.weight for SD format
# Reshaping decoder.mid.attn_1.v.weight for SD format
# Reshaping decoder.mid.attn_1.proj_out.weight for SD format
# [*] Converted ckpt saved at /content/drive/MyDrive/stable_diffusion_weights/dreambooth_aaron_hnatiw/800/model.ckpt

# %% [markdown]
# ## Inference

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline, DDIMScheduler
from IPython.display import display

model_path = WEIGHTS_DIR             # If you want to use previously trained model saved in gdrive, replace this with the full path of model in gdrive

scheduler = DDIMScheduler(beta_start=0.00085, beta_end=0.012, beta_schedule="scaled_linear", clip_sample=False, set_alpha_to_one=False)
pipe = StableDiffusionPipeline.from_pretrained(model_path, scheduler=scheduler, safety_checker=None, torch_dtype=torch.float16).to("cuda")

g_cuda = None
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]

# %%
#@markdown Can set random seed here for reproducibility.
g_cuda = torch.Generator(device='cuda')
seed = 52362 #@param {type:"number"}
g_cuda.manual_seed(seed)

# %%
#@title Run for generating images.

prompt = "photo of Aaron Hnatiw as a wizard" #@param {type:"string"}
negative_prompt = "" #@param {type:"string"}
num_samples = 4 #@param {type:"number"}
guidance_scale = 7.5 #@param {type:"number"}
num_inference_steps = 50 #@param {type:"number"}
height = 512 #@param {type:"number"}
width = 512 #@param {type:"number"}

with autocast("cuda"), torch.inference_mode():
    images = pipe(
        prompt,
        height=height,
        width=width,
        negative_prompt=negative_prompt,
        num_images_per_prompt=num_samples,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=g_cuda
    ).images

for img in images:
    display(img)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F312A1BDE90>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F312A1BDB50>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F312A1C5790>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F312A1C5710>

# %%
#@markdown Run Gradio UI for generating images.
import gradio as gr

def inference(prompt, negative_prompt, num_samples, height=512, width=512, num_inference_steps=50, guidance_scale=7.5):
    with torch.autocast("cuda"), torch.inference_mode():
        return pipe(
                prompt, height=int(height), width=int(width),
                negative_prompt=negative_prompt,
                num_images_per_prompt=int(num_samples),
                num_inference_steps=int(num_inference_steps), guidance_scale=guidance_scale,
                generator=g_cuda
            ).images

with gr.Blocks() as demo:
    with gr.Row():
        with gr.Column():
            prompt = gr.Textbox(label="Prompt", value="photo of sks dog in a bucket")
            negative_prompt = gr.Textbox(label="Negative Prompt", value="")
            run = gr.Button(value="Generate")
            with gr.Row():
                num_samples = gr.Number(label="Number of Samples", value=4)
                guidance_scale = gr.Number(label="Guidance Scale", value=7.5)
            with gr.Row():
                height = gr.Number(label="Height", value=512)
                width = gr.Number(label="Width", value=512)
            num_inference_steps = gr.Slider(label="Steps", value=50)
        with gr.Column():
            gallery = gr.Gallery()

    run.click(inference, inputs=[prompt, negative_prompt, num_samples, height, width, num_inference_steps, guidance_scale], outputs=gallery)

demo.launch(debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://a645435f533a9821.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://a645435f533a9821.gradio.app" width="900" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
#@title (Optional) Delete diffuser and old weights and only keep the ckpt to free up drive space.

#@markdown [ ! ] Caution, Only execute if you are sure u want to delete the diffuser format weights and only use the ckpt.
import shutil
from glob import glob
import os
for f in glob(OUTPUT_DIR+os.sep+"*"):
    if f != WEIGHTS_DIR:
        shutil.rmtree(f)
        print("Deleted", f)
for f in glob(WEIGHTS_DIR+"/*"):
    if not f.endswith(".ckpt") or not f.endswith(".json"):
        try:
            shutil.rmtree(f)
        except NotADirectoryError:
            continue
        print("Deleted", f)

# %%
#@title Free runtime memory
exit()
